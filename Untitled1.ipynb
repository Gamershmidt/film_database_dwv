# %%
import requests
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_highest-grossing_films"

response = requests.get(url)
soup = BeautifulSoup(response.content, "html.parser")

table = soup.find('table', {'class': 'wikitable'})

films_data = []

for row in table.find_all('tr')[1:]:  
    columns = row.find_all('td')
    
    if len(columns) > 4:  
        title_tag = row.find('th').find('a')  
        title = title_tag.get_text(strip=True) if title_tag else None
        film_url = "https://en.wikipedia.org" + title_tag['href'] if title_tag else None
        
        release_year = columns[3].get_text(strip=True)
        
        box_office_revenue = columns[2].get_text(strip=True)
        
        country_of_origin = columns[4].get_text(strip=True)
        
        if film_url:
            film_response = requests.get(film_url)
            film_soup = BeautifulSoup(film_response.content, "html.parser")
            
            director_tag = film_soup.find('th', string='Directed by')
            directors = None
            if director_tag:
                # print(director_tag.find_next('td').get_text())
                directors_raw = director_tag.find_next('td').get_text(strip=True)
                directors_cleaned = re.sub(r'\[\d+\]', '', directors_raw)
                directors_split = re.sub(r'([a-z])([A-Z])', r'\1, \2', directors_cleaned)
                directors = directors_split.split(',')[0].strip()

                
                # print(directors)
            
            country_tag = film_soup.find('th', string='Country')
            if country_tag is None:
                country_tag = film_soup.find('th', string='Countries')
            film_country = None
            if country_tag:
                directors_raw = country_tag.find_next('td').get_text(strip=True)
                directors_cleaned = re.sub(r'\[\d+\]', '', directors_raw)
                directors_split = re.sub(r'([a-z])([A-Z])', r'\1, \2', directors_cleaned)
                film_country = directors_split.split(',')[0].strip()

        film_data = {
            "Title": title,
            "Release Year": int(release_year) if release_year.isdigit() else None,
            "Directors": directors,
            "Box Office Revenue": box_office_revenue,
            "Country of Origin": film_country or country_of_origin  
        }
        # print(film_data)
        films_data.append(film_data)

for film in films_data:
    print(film)
# Out:
# {'Title': 'Avatar', 'Release Year': 2009, 'Directors': 'James Cameron', 'Box Office Revenue': '$2,923,706,026', 'Country of Origin': 'United Kingdom'}
# {'Title': 'Avengers: Endgame', 'Release Year': 2019, 'Directors': 'Anthony Russo', 'Box Office Revenue': '$2,797,501,328', 'Country of Origin': 'United States'}
# {'Title': 'Avatar: The Way of Water', 'Release Year': 2022, 'Directors': 'James Cameron', 'Box Office Revenue': '$2,320,250,281', 'Country of Origin': 'United States'}
# {'Title': 'Titanic', 'Release Year': 1997, 'Directors': 'James Cameron', 'Box Office Revenue': 'T$2,257,844,554', 'Country of Origin': 'United States'}
# {'Title': 'Star Wars: The Force Awakens', 'Release Year': 2015, 'Directors': 'J. J. Abrams', 'Box Office Revenue': '$2,068,223,624', 'Country of Origin': 'United States'}
# {'Title': 'Avengers: Infinity War', 'Release Year': 2018, 'Directors': 'Anthony Russo', 'Box Office Revenue': '$2,048,359,754', 'Country of Origin': 'United States'}
# {'Title': 'Ne Zha 2', 'Release Year': 2025, 'Directors': 'Jiaozi', 'Box Office Revenue': '$1,940,794,560', 'Country of Origin': 'China'}
# {'Title': 'Spider-Man: No Way Home', 'Release Year': 2021, 'Directors': 'Jon Watts', 'Box Office Revenue': 'SM$1,922,598,800', 'Country of Origin': 'United States'}
# {'Title': 'Inside Out 2', 'Release Year': 2024, 'Directors': 'Kelsey Mann', 'Box Office Revenue': '$1,698,863,816', 'Country of Origin': 'United States'}
# {'Title': 'Jurassic World', 'Release Year': 2015, 'Directors': 'Colin Trevorrow', 'Box Office Revenue': '$1,671,537,444', 'Country of Origin': 'United States'}
# {'Title': 'The Lion King', 'Release Year': 2019, 'Directors': 'Jon Favreau', 'Box Office Revenue': '$1,656,943,394', 'Country of Origin': 'United States'}
# {'Title': 'The Avengers', 'Release Year': 2012, 'Directors': 'Joss Whedon', 'Box Office Revenue': '$1,518,815,515', 'Country of Origin': 'United States'}
# {'Title': 'Furious 7', 'Release Year': 2015, 'Directors': 'James Wan', 'Box Office Revenue': '$1,515,341,399', 'Country of Origin': 'United States'}
# {'Title': 'Top Gun: Maverick', 'Release Year': 2022, 'Directors': 'Joseph Kosinski', 'Box Office Revenue': '$1,495,696,292', 'Country of Origin': 'United States'}
# {'Title': 'Frozen 2', 'Release Year': 2019, 'Directors': 'Chris Buck', 'Box Office Revenue': '$1,450,026,933', 'Country of Origin': 'United States'}
# {'Title': 'Barbie', 'Release Year': 2023, 'Directors': 'Greta Gerwig', 'Box Office Revenue': '$1,447,038,421', 'Country of Origin': 'United States'}
# {'Title': 'Avengers: Age of Ultron', 'Release Year': 2015, 'Directors': 'Joss Whedon', 'Box Office Revenue': '$1,402,809,540', 'Country of Origin': 'United States'}
# {'Title': 'The Super Mario Bros. Movie', 'Release Year': 2023, 'Directors': 'Aaron Horvath', 'Box Office Revenue': '$1,362,566,989', 'Country of Origin': 'United States'}
# {'Title': 'Black Panther', 'Release Year': 2018, 'Directors': 'Ryan Coogler', 'Box Office Revenue': '$1,347,280,838', 'Country of Origin': 'United States'}
# {'Title': 'Harry Potter and the Deathly Hallows – Part 2', 'Release Year': 2011, 'Directors': 'David Yates', 'Box Office Revenue': '$1,342,139,727', 'Country of Origin': 'United Kingdom'}
# {'Title': 'Deadpool & Wolverine', 'Release Year': 2024, 'Directors': 'Shawn Levy', 'Box Office Revenue': '$1,338,073,645', 'Country of Origin': 'United States'}
# {'Title': 'Star Wars: The Last Jedi', 'Release Year': 2017, 'Directors': 'Rian Johnson', 'Box Office Revenue': '$1,332,539,889', 'Country of Origin': 'United States'}
# {'Title': 'Jurassic World: Fallen Kingdom', 'Release Year': 2018, 'Directors': 'J. A. Bayona', 'Box Office Revenue': '$1,308,473,425', 'Country of Origin': 'China'}
# {'Title': 'Frozen', 'Release Year': 2013, 'Directors': 'Chris Buck', 'Box Office Revenue': 'F$1,290,000,000', 'Country of Origin': 'United States'}
# {'Title': 'Beauty and the Beast', 'Release Year': 2017, 'Directors': 'Bill Condon', 'Box Office Revenue': '$1,263,521,126', 'Country of Origin': 'United States'}
# {'Title': 'Incredibles 2', 'Release Year': 2018, 'Directors': 'Brad Bird', 'Box Office Revenue': '$1,242,805,359', 'Country of Origin': 'United States'}
# {'Title': 'The Fate of the Furious', 'Release Year': 2017, 'Directors': 'F. Gary Gray', 'Box Office Revenue': 'F8$1,238,764,765', 'Country of Origin': 'United States'}
# {'Title': 'Iron Man 3', 'Release Year': 2013, 'Directors': 'Shane Black', 'Box Office Revenue': '$1,214,811,252', 'Country of Origin': 'United States'}
# {'Title': 'Minions', 'Release Year': 2015, 'Directors': 'Pierre Coffin', 'Box Office Revenue': '$1,159,444,662', 'Country of Origin': 'United States'}
# {'Title': 'Captain America: Civil War', 'Release Year': 2016, 'Directors': 'Anthony Russo', 'Box Office Revenue': '$1,153,337,496', 'Country of Origin': 'United States'}
# {'Title': 'Aquaman', 'Release Year': 2018, 'Directors': 'James Wan', 'Box Office Revenue': '$1,148,528,393', 'Country of Origin': 'United States'}
# {'Title': 'The Lord of the Rings: The Return of the King', 'Release Year': 2003, 'Directors': 'Peter Jackson', 'Box Office Revenue': '$1,147,997,407', 'Country of Origin': 'New Zealand'}
# {'Title': 'Spider-Man: Far From Home', 'Release Year': 2019, 'Directors': 'Jon Watts', 'Box Office Revenue': '$1,132,679,685', 'Country of Origin': 'United States'}
# {'Title': 'Captain Marvel', 'Release Year': 2019, 'Directors': 'Anna Boden', 'Box Office Revenue': '$1,128,274,794', 'Country of Origin': 'United States'}
# {'Title': 'Transformers: Dark of the Moon', 'Release Year': 2011, 'Directors': 'Michael Bay', 'Box Office Revenue': '$1,123,794,079', 'Country of Origin': 'United States'}
# {'Title': 'Skyfall', 'Release Year': 2012, 'Directors': 'Sam Mendes', 'Box Office Revenue': '$1,108,594,137', 'Country of Origin': 'United Kingdom'}
# {'Title': 'Transformers: Age of Extinction', 'Release Year': 2014, 'Directors': 'Michael Bay', 'Box Office Revenue': '$1,104,054,072', 'Country of Origin': 'United States'}
# {'Title': 'The Dark Knight Rises', 'Release Year': 2012, 'Directors': 'Christopher Nolan', 'Box Office Revenue': '$1,081,169,825', 'Country of Origin': 'United States'}
# {'Title': 'Joker', 'Release Year': 2019, 'Directors': 'Todd Phillips', 'Box Office Revenue': '$1,074,458,282', 'Country of Origin': 'United States'}
# {'Title': 'Star Wars: The Rise of Skywalker', 'Release Year': 2019, 'Directors': 'J. J. Abrams', 'Box Office Revenue': '$1,074,144,248', 'Country of Origin': 'United States'}
# {'Title': 'Toy Story 4', 'Release Year': 2019, 'Directors': 'Josh Cooley', 'Box Office Revenue': '$1,073,394,593', 'Country of Origin': 'United States'}
# {'Title': 'Toy Story 3', 'Release Year': 2010, 'Directors': 'Lee Unkrich', 'Box Office Revenue': '$1,066,970,811', 'Country of Origin': 'United States'}
# {'Title': "Pirates of the Caribbean: Dead Man's Chest", 'Release Year': 2006, 'Directors': 'Gore Verbinski', 'Box Office Revenue': '$1,066,179,747', 'Country of Origin': 'United States'}
# {'Title': 'Rogue One: A Star Wars Story', 'Release Year': 2016, 'Directors': 'Gareth Edwards', 'Box Office Revenue': '$1,057,420,387', 'Country of Origin': 'United States'}
# {'Title': 'Moana 2', 'Release Year': 2024, 'Directors': 'David Derrick Jr.Jason Hand', 'Box Office Revenue': '$1,053,502,480', 'Country of Origin': 'United States'}
# {'Title': 'Aladdin', 'Release Year': 2019, 'Directors': 'Guy Ritchie', 'Box Office Revenue': '$1,050,693,953', 'Country of Origin': 'United States'}
# {'Title': 'Star Wars: Episode I – The Phantom Menace', 'Release Year': 1999, 'Directors': 'George Lucas', 'Box Office Revenue': '$1,046,515,409', 'Country of Origin': 'United States'}
# {'Title': 'Pirates of the Caribbean: On Stranger Tides', 'Release Year': 2011, 'Directors': 'Rob Marshall', 'Box Office Revenue': '$1,045,713,802', 'Country of Origin': 'United States'}
# {'Title': 'Jurassic Park', 'Release Year': 1993, 'Directors': 'Steven Spielberg', 'Box Office Revenue': '$1,037,535,230', 'Country of Origin': 'United States'}
# {'Title': 'Despicable Me 3', 'Release Year': 2017, 'Directors': 'Pierre Coffin', 'Box Office Revenue': '$1,034,800,131', 'Country of Origin': 'United States'}

# %%
import sqlite3
import requests
from bs4 import BeautifulSoup
import re

# Initialize SQLite database
conn = sqlite3.connect('films.db')
cursor = conn.cursor()

# Create films table
cursor.execute('''
    CREATE TABLE IF NOT EXISTS films (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        title TEXT NOT NULL,
        release_year INTEGER,
        director TEXT,
        box_office TEXT,
        country TEXT
    )
''')

for film in films_data:
    cursor.execute('''
            INSERT INTO films (title, release_year, director, box_office, country)
            VALUES (?, ?, ?, ?, ?)
        ''', (film['Title'], int(film['Release Year']) if release_year.isdigit() else None, film['Directors'], film['Box Office Revenue'], film['Country of Origin']))


conn.commit()
conn.close()

print("Data inserted into the films table successfully.")
# Out:
# Data inserted into the films table successfully.

# %%
import sqlite3
import json

conn = sqlite3.connect('films.db')
cursor = conn.cursor()

cursor.execute("SELECT * FROM films")

films = cursor.fetchall()
films_data  = []
for film in films:
    film_data = {
            "Title": film[1],
            "Release Year": film[2],
            "Directors": film[3],
            "Box Office Revenue": film[4],
            "Country of Origin": film[5] 
        }
    films_data.append(film_data)
    
with open('films_data.json', 'w') as json_file:
    json.dump(films_data, json_file, indent=4)
conn.close()
